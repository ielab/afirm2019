# %% [markdown]
# # Access a Term Vector
#
#
# A term vector is information and statistics in the fields of a particular document. Term vectors in Elasticsearch are generated on the fly.
#
#
#
# ## Getting Started
#
# In this example, we will use the Elaticsearch Python API. First, we will import and set-up all of the required Python modules and variables we will use later on. Additionally, if you wish to use `curl` instead of the Python API, the corresponding command line function has been commented above each API request.

# %%
from elasticsearch import Elasticsearch
import pandas as pd
es = Elasticsearch(urls=['localhost'], port=9200)

# %% [markdown]
# Let's examine what a document in this index looks like. (this operation may take few seconds)

# %%
# This query will retrieve every document in the index.
query = {
    'query': {
        'match_all': {}
    }
}

# Send a search request to Elasticsearch.
# curl -X GET localhost:9200/goma/_search -H 'Content-Type: application/json' -d @query.json
res = es.search(index='goma', body=query)

# The response is a json object, the listing is nested inside it.
# Here we are accessing the first hit in the listing.
res['hits']['hits'][0]
# Out:
# {'_index': 'goma',
#  '_type': 'doc',
#  '_id': 'QSlkSGgBOPedV1qMWTBT',
#  '_score': 1.0,
#  '_source': {'qagoma_events': [{'id': '118628',
#     'title': 'Australian Art Collection',
#     'description': 'An exciting reimagining of the Australian Art Collection has recently opened. Our curators, along with Director Chris Saines, have taken this rare opportunity to re-present the Gallery&rsquo;s Australian art holdings, collected for more than 120 years, in new and innovative ways.',
#     'start_time': '2017-09-30 10:00:00',
#     'end_time': '2028-12-31 17:00:00',
#     'stop_date': '2028-12-31',
#     'thumbnail': 'https://www.qagoma.qld.gov.au/__data/assets/image/0005/118733/APP_sleeping-bride.jpg',
#     'location': 'QAG: Gallery 10; Gallery 11; Gallery 12; Gallery 13; Josephine Ulrick &amp; Win Schubert Galleries',
#     'entry': 'Free',
#     'available': 'Yes',
#     'category': '',
#     'link': 'https://www.qagoma.qld.gov.au/whats-on/exhibitions/australian-collection',
#     'sessions': [{'session_count': '0',
#       'date_start': '2017-10-01 10:00:00',
#       'date_end': '2017-10-01 17:00:00'},
#      {'session_count': '1',
#       'date_start': '2017-10-02 10:00:00',
#       'date_end': '2017-10-02 17:00:00'},
#      {'session_count': '2',
#       'date_start': '2017-10-03 10:00:00',
#       'date_end': '2017-10-03 17:00:00'},
#      {'session_count': '3',
#       'date_start': '2017-10-04 10:00:00',
#       'date_end': '2017-10-04 17:00:00'},
#      {'session_count': '4',
#       'date_start': '2017-10-05 10:00:00',
#       'date_end': '2017-10-05 17:00:00'},
#      {'session_count': '5',
#       'date_start': '2017-10-06 10:00:00',
#       'date_end': '2017-10-06 17:00:00'},
#      {'session_count': '6',
#       'date_start': '2017-10-07 10:00:00',
#       'date_end': '2017-10-07 17:00:00'},
#      {'session_count': '7',
#       'date_start': '2017-10-08 10:00:00',
#       'date_end': '2017-10-08 17:00:00'},
#      {'session_count': '8',
#       'date_start': '2017-10-09 10:00:00',
#       'date_end': '2017-10-09 17:00:00'},
#      {'session_count': '9',
#       'date_start': '2017-10-10 10:00:00',
#       'date_end': '2017-10-10 17:00:00'},
#      {'session_count': '10',
#       'date_start': '2017-10-11 10:00:00',
#       'date_end': '2017-10-11 17:00:00'},
#      {'session_count': '11',
#       'date_start': '2017-10-12 10:00:00',
#       'date_end': '2017-10-12 17:00:00'},
#      {'session_count': '12',
#       'date_start': '2017-10-13 10:00:00',
#       'date_end': '2017-10-13 17:00:00'},
#      {'session_count': '13',
#       'date_start': '2017-10-14 10:00:00',
#       'date_end': '2017-10-14 17:00:00'},
#      {'session_count': '14',
#       'date_start': '2017-10-15 10:00:00',
#       'date_end': '2017-10-15 17:00:00'},
#      {'session_count': '15',
#       'date_start': '2017-10-16 10:00:00',
#       'date_end': '2017-10-16 17:00:00'},
#      {'session_count': '16',
#       'date_start': '2017-10-17 10:00:00',
#       'date_end': '2017-10-17 17:00:00'},
#      {'session_count': '17',
#       'date_start': '2017-10-18 10:00:00',
#       'date_end': '2017-10-18 17:00:00'},
#      {'session_count': '18',
#       'date_start': '2017-10-19 10:00:00',
#       'date_end': '2017-10-19 17:00:00'},
#      {'session_count': '19',
#       'date_start': '2017-10-20 10:00:00',
#       'date_end': '2017-10-20 17:00:00'},
#      {'session_count': '20',
#       'date_start': '2017-10-21 10:00:00',
#       'date_end': '2017-10-21 17:00:00'},
#      {'session_count': '21',
#       'date_start': '2017-10-22 10:00:00',
#       'date_end': '2017-10-22 17:00:00'},
#      {'session_count': '22',
#       'date_start': '2017-10-23 10:00:00',
#       'date_end': '2017-10-23 17:00:00'},
#      {'session_count': '23',
#       'date_start': '2017-10-24 10:00:00',
#       'date_end': '2017-10-24 17:00:00'},
#      {'session_count': '24',
#       'date_start': '2017-10-25 10:00:00',
#       'date_end': '2017-10-25 17:00:00'},
#      {'session_count': '25',
#       'date_start': '2017-10-26 10:00:00',
#       'date_end': '2017-10-26 17:00:00'},
#      {'session_count': '26',
#       'date_start': '2017-10-27 10:00:00',
#       'date_end': '2017-10-27 17:00:00'},
#      {'session_count': '27',
#       'date_start': '2017-10-28 10:00:00',
#       'date_end': '2017-10-28 17:00:00'},
#      {'session_count': '28',
#       'date_start': '2017-10-29 10:00:00',
#       'date_end': '2017-10-29 17:00:00'},
#      {'session_count': '29',
#       'date_start': '2017-10-30 10:00:00',
#       'date_end': '2017-10-30 17:00:00'},
#      {'session_count': '30',
#       'date_start': '2017-10-31 10:00:00',
#       'date_end': '2017-10-31 17:00:00'},
#      {'session_count': '31',
#       'date_start': '2017-11-01 10:00:00',
#       'date_end': '2017-11-01 17:00:00'},
#      {'session_count': '32',
#       'date_start': '2017-11-02 10:00:00',
#       'date_end': '2017-11-02 17:00:00'},
#      {'session_count': '33',
#       'date_start': '2017-11-03 10:00:00',
#       'date_end': '2017-11-03 17:00:00'},
#      {'session_count': '34',
#       'date_start': '2017-11-04 10:00:00',
#       'date_end': '2017-11-04 17:00:00'},
#      {'session_count': '35',
#       'date_start': '2017-11-05 10:00:00',
#       'date_end': '2017-11-05 17:00:00'},
#      {'session_count': '36',
#       'date_start': '2017-11-06 10:00:00',
#       'date_end': '2017-11-06 17:00:00'},
#      {'session_count': '37',
#       'date_start': '2017-11-07 10:00:00',
#       'date_end': '2017-11-07 17:00:00'},
#      {'session_count': '38',
#       'date_start': '2017-11-08 10:00:00',
#       'date_end': '2017-11-08 17:00:00'},
#      {'session_count': '39',
#       'date_start': '2017-11-09 10:00:00',
#       'date_end': '2017-11-09 17:00:00'},
#      {'session_count': '40',
#       'date_start': '2017-11-10 10:00:00',
#       'date_end': '2017-11-10 17:00:00'},
#      {'session_count': '41',
#       'date_start': '2017-11-11 10:00:00',
#       'date_end': '2017-11-11 17:00:00'},
#      {'session_count': '42',
#       'date_start': '2017-11-12 10:00:00',
#       'date_end': '2017-11-12 17:00:00'},
#      {'session_count': '43',
#       'date_start': '2017-11-13 10:00:00',
#       'date_end': '2017-11-13 17:00:00'},
#      {'session_count': '44',
#       'date_start': '2017-11-14 10:00:00',
#       'date_end': '2017-11-14 17:00:00'},
#      {'session_count': '45',
#       'date_start': '2017-11-15 10:00:00',
#       'date_end': '2017-11-15 17:00:00'},
#      {'session_count': '46',
#       'date_start': '2017-11-16 10:00:00',
#       'date_end': '2017-11-16 17:00:00'},
#      {'session_count': '47',
#       'date_start': '2017-11-17 10:00:00',
#       'date_end': '2017-11-17 17:00:00'},
#      {'session_count': '48',
#       'date_start': '2017-11-18 10:00:00',
#       'date_end': '2017-11-18 17:00:00'},
#      {'session_count': '49',
#       'date_start': '2017-11-19 10:00:00',
#       'date_end': '2017-11-19 17:00:00'},
#      {'session_count': '50',
#       'date_start': '2017-11-20 10:00:00',
#       'date_end': '2017-11-20 17:00:00'},
#      {'session_count': '51',
#       'date_start': '2017-11-21 10:00:00',
#       'date_end': '2017-11-21 17:00:00'},
#      {'session_count': '52',
#       'date_start': '2017-11-22 10:00:00',
#       'date_end': '2017-11-22 17:00:00'},
#      {'session_count': '53',
#       'date_start': '2017-11-23 10:00:00',
#       'date_end': '2017-11-23 17:00:00'},
#      {'session_count': '54',
#       'date_start': '2017-11-24 10:00:00',
#       'date_end': '2017-11-24 17:00:00'},
#      {'session_count': '55',
#       'date_start': '2017-11-25 10:00:00',
#       'date_end': '2017-11-25 17:00:00'},
#      {'session_count': '56',
#       'date_start': '2017-11-26 10:00:00',
#       'date_end': '2017-11-26 17:00:00'},
#      {'session_count': '57',
#       'date_start': '2017-11-27 10:00:00',
#       'date_end': '2017-11-27 17:00:00'},
#      {'session_count': '58',
#       'date_start': '2017-11-28 10:00:00',
#       'date_end': '2017-11-28 17:00:00'},
#      {'session_count': '59',
#       'date_start': '2017-11-29 10:00:00',
#       'date_end': '2017-11-29 17:00:00'},
#      {'session_count': '60',
#       'date_start': '2017-11-30 10:00:00',
#       'date_end': '2017-11-30 17:00:00'},
#      {'session_count': '61',
#       'date_start': '2017-12-01 10:00:00',
#       'date_end': '2017-12-01 17:00:00'},
#      {'session_count': '62',
#       'date_start': '2017-12-02 10:00:00',
#       'date_end': '2017-12-02 17:00:00'},
#      {'session_count': '63',
#       'date_start': '2017-12-03 10:00:00',
#       'date_end': '2017-12-03 17:00:00'},
#      {'session_count': '64',
#       'date_start': '2017-12-04 10:00:00',
#       'date_end': '2017-12-04 17:00:00'},
#      {'session_count': '65',
#       'date_start': '2017-12-05 10:00:00',
#       'date_end': '2017-12-05 17:00:00'},
#      {'session_count': '66',
#       'date_start': '2017-12-06 10:00:00',
#       'date_end': '2017-12-06 17:00:00'},
#      {'session_count': '67',
#       'date_start': '2017-12-07 10:00:00',
#       'date_end': '2017-12-07 17:00:00'},
#      {'session_count': '68',
#       'date_start': '2017-12-08 10:00:00',
#       'date_end': '2017-12-08 17:00:00'},
#      {'session_count': '69',
#       'date_start': '2017-12-09 10:00:00',
#       'date_end': '2017-12-09 17:00:00'},
#      {'session_count': '70',
#       'date_start': '2017-12-10 10:00:00',
#       'date_end': '2017-12-10 17:00:00'},
#      {'session_count': '71',
#       'date_start': '2017-12-11 10:00:00',
#       'date_end': '2017-12-11 17:00:00'},
#      {'session_count': '72',
#       'date_start': '2017-12-12 10:00:00',
#       'date_end': '2017-12-12 17:00:00'},
#      {'session_count': '73',
#       'date_start': '2017-12-13 10:00:00',
#       'date_end': '2017-12-13 17:00:00'},
#      {'session_count': '74',
#       'date_start': '2017-12-14 10:00:00',
#       'date_end': '2017-12-14 17:00:00'},
#      {'session_count': '75',
#       'date_start': '2017-12-15 10:00:00',
#       'date_end': '2017-12-15 17:00:00'},
#      {'session_count': '76',
#       'date_start': '2017-12-16 10:00:00',
#       'date_end': '2017-12-16 17:00:00'},
#      {'session_count': '77',
#       'date_start': '2017-12-17 10:00:00',
#       'date_end': '2017-12-17 17:00:00'},
#      {'session_count': '78',
#       'date_start': '2017-12-18 10:00:00',
#       'date_end': '2017-12-18 17:00:00'},
#      {'session_count': '79',
#       'date_start': '2017-12-19 10:00:00',
#       'date_end': '2017-12-19 17:00:00'},
#      {'session_count': '80',
#       'date_start': '2017-12-20 10:00:00',
#       'date_end': '2017-12-20 17:00:00'},
#      {'session_count': '81',
#       'date_start': '2017-12-21 10:00:00',
#       'date_end': '2017-12-21 17:00:00'},
#      {'session_count': '82',
#       'date_start': '2017-12-22 10:00:00',
#       'date_end': '2017-12-22 17:00:00'},
#      {'session_count': '83',
#       'date_start': '2017-12-23 10:00:00',
#       'date_end': '2017-12-23 17:00:00'},
#      {'session_count': '84',
#       'date_start': '2017-12-24 10:00:00',
#       'date_end': '2017-12-24 17:00:00'},
#      {'session_count': '85',
#       'date_start': '2017-12-27 10:00:00',
#       'date_end': '2017-12-27 17:00:00'},
#      {'session_count': '86',
#       'date_start': '2017-12-28 10:00:00',
#       'date_end': '2017-12-28 17:00:00'},
#      {'session_count': '87',
#       'date_start': '2017-12-29 10:00:00',
#       'date_end': '2017-12-29 17:00:00'},
#      {'session_count': '88',
#       'date_start': '2017-12-30 10:00:00',
#       'date_end': '2017-12-30 17:00:00'},
#      {'session_count': '89',
#       'date_start': '2017-12-31 10:00:00',
#       'date_end': '2017-12-31 17:00:00'},
#      {'session_count': '90',
#       'date_start': '2018-01-01 10:00:00',
#       'date_end': '2018-01-01 17:00:00'},
#      {'session_count': '91',
#       'date_start': '2018-01-02 10:00:00',
#       'date_end': '2018-01-02 17:00:00'},
#      {'session_count': '92',
#       'date_start': '2018-01-03 10:00:00',
#       'date_end': '2018-01-03 17:00:00'},
#      {'session_count': '93',
#       'date_start': '2018-01-04 10:00:00',
#       'date_end': '2018-01-04 17:00:00'},
#      {'session_count': '94',
#       'date_start': '2018-01-05 10:00:00',
#       'date_end': '2018-01-05 17:00:00'},
#      {'session_count': '95',
#       'date_start': '2018-01-06 10:00:00',
#       'date_end': '2018-01-06 17:00:00'},
#      {'session_count': '96',
#       'date_start': '2018-01-07 10:00:00',
#       'date_end': '2018-01-07 17:00:00'},
#      {'session_count': '97',
#       'date_start': '2018-01-08 10:00:00',
#       'date_end': '2018-01-08 17:00:00'},
#      {'session_count': '98',
#       'date_start': '2018-01-09 10:00:00',
#       'date_end': '2018-01-09 17:00:00'},
#      {'session_count': '99',
#       'date_start': '2018-01-10 10:00:00',
#       'date_end': '2018-01-10 17:00:00'},
#      {'session_count': '100',
#       'date_start': '2018-01-11 10:00:00',
#       'date_end': '2018-01-11 17:00:00'},
#      {'session_count': '101',
#       'date_start': '2018-01-12 10:00:00',
#       'date_end': '2018-01-12 17:00:00'},
#      {'session_count': '102',
#       'date_start': '2018-01-13 10:00:00',
#       'date_end': '2018-01-13 17:00:00'},
#      {'session_count': '103',
#       'date_start': '2018-01-14 10:00:00',
#       'date_end': '2018-01-14 17:00:00'},
#      {'session_count': '104',
#       'date_start': '2018-01-15 10:00:00',
#       'date_end': '2018-01-15 17:00:00'},
#      {'session_count': '105',
#       'date_start': '2018-01-16 10:00:00',
#       'date_end': '2018-01-16 17:00:00'},
#      {'session_count': '106',
#       'date_start': '2018-01-17 10:00:00',
#       'date_end': '2018-01-17 17:00:00'},
#      {'session_count': '107',
#       'date_start': '2018-01-18 10:00:00',
#       'date_end': '2018-01-18 17:00:00'},
#      {'session_count': '108',
#       'date_start': '2018-01-19 10:00:00',
#       'date_end': '2018-01-19 17:00:00'},
#      {'session_count': '109',
#       'date_start': '2018-01-20 10:00:00',
#       'date_end': '2018-01-20 17:00:00'},
#      {'session_count': '110',
#       'date_start': '2018-01-21 10:00:00',
#       'date_end': '2018-01-21 17:00:00'},
#      {'session_count': '111',
#       'date_start': '2018-01-22 10:00:00',
#       'date_end': '2018-01-22 17:00:00'},
#      {'session_count': '112',
#       'date_start': '2018-01-23 10:00:00',
#       'date_end': '2018-01-23 17:00:00'},
#      {'session_count': '113',
#       'date_start': '2018-01-24 10:00:00',
#       'date_end': '2018-01-24 17:00:00'},
#      {'session_count': '114',
#       'date_start': '2018-01-25 10:00:00',
#       'date_end': '2018-01-25 17:00:00'},
#      {'session_count': '115',
#       'date_start': '2018-01-26 10:00:00',
#       'date_end': '2018-01-26 17:00:00'},
#      {'session_count': '116',
#       'date_start': '2018-01-27 10:00:00',
#       'date_end': '2018-01-27 17:00:00'},
#      {'session_count': '117',
#       'date_start': '2018-01-28 10:00:00',
#       'date_end': '2018-01-28 17:00:00'},
#      {'session_count': '118',
#       'date_start': '2018-01-29 10:00:00',
#       'date_end': '2018-01-29 17:00:00'},
#      {'session_count': '119',
#       'date_start': '2018-01-30 10:00:00',
#       'date_end': '2018-01-30 17:00:00'},
#      {'session_count': '120',
#       'date_start': '2018-01-31 10:00:00',
#       'date_end': '2018-01-31 17:00:00'},
#      {'session_count': '121',
#       'date_start': '2018-02-01 10:00:00',
#       'date_end': '2018-02-01 17:00:00'},
#      {'session_count': '122',
#       'date_start': '2018-02-02 10:00:00',
#       'date_end': '2018-02-02 17:00:00'},
#      {'session_count': '123',
#       'date_start': '2018-02-03 10:00:00',
#       'date_end': '2018-02-03 17:00:00'},
#      {'session_count': '124',
#       'date_start': '2018-02-04 10:00:00',
#       'date_end': '2018-02-04 17:00:00'},
#      {'session_count': '125',
#       'date_start': '2018-02-05 10:00:00',
#       'date_end': '2018-02-05 17:00:00'},
#      {'session_count': '126',
#       'date_start': '2018-02-06 10:00:00',
#       'date_end': '2018-02-06 17:00:00'},
#      {'session_count': '127',
#       'date_start': '2018-02-07 10:00:00',
#       'date_end': '2018-02-07 17:00:00'},
#      {'session_count': '128',
#       'date_start': '2018-02-08 10:00:00',
#       'date_end': '2018-02-08 17:00:00'},
#      {'session_count': '129',
#       'date_start': '2018-02-09 10:00:00',
#       'date_end': '2018-02-09 17:00:00'},
#      {'session_count': '130',
#       'date_start': '2018-02-10 10:00:00',
#       'date_end': '2018-02-10 17:00:00'},
#      {'session_count': '131',
#       'date_start': '2018-02-11 10:00:00',
#       'date_end': '2018-02-11 17:00:00'},
#      {'session_count': '132',
#       'date_start': '2018-02-12 10:00:00',
#       'date_end': '2018-02-12 17:00:00'},
#      {'session_count': '133',
#       'date_start': '2018-02-13 10:00:00',
#       'date_end': '2018-02-13 17:00:00'},
#      {'session_count': '134',
#       'date_start': '2018-02-14 10:00:00',
#       'date_end': '2018-02-14 17:00:00'},
#      {'session_count': '135',
#       'date_start': '2018-02-15 10:00:00',
#       'date_end': '2018-02-15 17:00:00'},
#      {'session_count': '136',
#       'date_start': '2018-02-16 10:00:00',
#       'date_end': '2018-02-16 17:00:00'},
#      {'session_count': '137',
#       'date_start': '2018-02-17 10:00:00',
#       'date_end': '2018-02-17 17:00:00'},
#      {'session_count': '138',
#       'date_start': '2018-02-18 10:00:00',
#       'date_end': '2018-02-18 17:00:00'},
#      {'session_count': '139',
#       'date_start': '2018-02-19 10:00:00',
#       'date_end': '2018-02-19 17:00:00'},
#      {'session_count': '140',
#       'date_start': '2018-02-20 10:00:00',
#       'date_end': '2018-02-20 17:00:00'},
#      {'session_count': '141',
#       'date_start': '2018-02-21 10:00:00',
#       'date_end': '2018-02-21 17:00:00'},
#      {'session_count': '142',
#       'date_start': '2018-02-22 10:00:00',
#       'date_end': '2018-02-22 17:00:00'},
#      {'session_count': '143',
#       'date_start': '2018-02-23 10:00:00',
#       'date_end': '2018-02-23 17:00:00'},
#      {'session_count': '144',
#       'date_start': '2018-02-24 10:00:00',
#       'date_end': '2018-02-24 17:00:00'},
#      {'session_count': '145',
#       'date_start': '2018-02-25 10:00:00',
#       'date_end': '2018-02-25 17:00:00'},
#      {'session_count': '146',
#       'date_start': '2018-02-26 10:00:00',
#       'date_end': '2018-02-26 17:00:00'},
#      {'session_count': '147',
#       'date_start': '2018-02-27 10:00:00',
#       'date_end': '2018-02-27 17:00:00'},
#      {'session_count': '148',
#       'date_start': '2018-02-28 10:00:00',
#       'date_end': '2018-02-28 17:00:00'},
#      {'session_count': '149',
#       'date_start': '2018-03-01 10:00:00',
#       'date_end': '2018-03-01 17:00:00'},
#      {'session_count': '150',
#       'date_start': '2018-03-02 10:00:00',
#       'date_end': '2018-03-02 17:00:00'},
#      {'session_count': '151',
#       'date_start': '2018-03-03 10:00:00',
#       'date_end': '2018-03-03 17:00:00'},
#      {'session_count': '152',
#       'date_start': '2018-03-04 10:00:00',
#       'date_end': '2018-03-04 17:00:00'},
#      {'session_count': '153',
#       'date_start': '2018-03-05 10:00:00',
#       'date_end': '2018-03-05 17:00:00'},
#      {'session_count': '154',
#       'date_start': '2018-03-06 10:00:00',
#       'date_end': '2018-03-06 17:00:00'},
#      {'session_count': '155',
#       'date_start': '2018-03-07 10:00:00',
#       'date_end': '2018-03-07 17:00:00'},
#      {'session_count': '156',
#       'date_start': '2018-03-08 10:00:00',
#       'date_end': '2018-03-08 17:00:00'},
#      {'session_count': '157',
#       'date_start': '2018-03-09 10:00:00',
#       'date_end': '2018-03-09 17:00:00'},
#      {'session_count': '158',
#       'date_start': '2018-03-10 10:00:00',
#       'date_end': '2018-03-10 17:00:00'},
#      {'session_count': '159',
#       'date_start': '2018-03-11 10:00:00',
#       'date_end': '2018-03-11 17:00:00'},
#      {'session_count': '160',
#       'date_start': '2018-03-12 10:00:00',
#       'date_end': '2018-03-12 17:00:00'},
#      {'session_count': '161',
#       'date_start': '2018-03-13 10:00:00',
#       'date_end': '2018-03-13 17:00:00'},
#      {'session_count': '162',
#       'date_start': '2018-03-14 10:00:00',
#       'date_end': '2018-03-14 17:00:00'},
#      {'session_count': '163',
#       'date_start': '2018-03-15 10:00:00',
#       'date_end': '2018-03-15 17:00:00'},
#      {'session_count': '164',
#       'date_start': '2018-03-16 10:00:00',
#       'date_end': '2018-03-16 17:00:00'},
#      {'session_count': '165',
#       'date_start': '2018-03-17 10:00:00',
#       'date_end': '2018-03-17 17:00:00'},
#      {'session_count': '166',
#       'date_start': '2018-03-18 10:00:00',
#       'date_end': '2018-03-18 17:00:00'},
#      {'session_count': '167',
#       'date_start': '2018-03-19 10:00:00',
#       'date_end': '2018-03-19 17:00:00'},
#      {'session_count': '168',
#       'date_start': '2018-03-20 10:00:00',
#       'date_end': '2018-03-20 17:00:00'},
#      {'session_count': '169',
#       'date_start': '2018-03-21 10:00:00',
#       'date_end': '2018-03-21 17:00:00'},
#      {'session_count': '170',
#       'date_start': '2018-03-22 10:00:00',
#       'date_end': '2018-03-22 17:00:00'},
#      {'session_count': '171',
#       'date_start': '2018-03-23 10:00:00',
#       'date_end': '2018-03-23 17:00:00'},
#      {'session_count': '172',
#       'date_start': '2018-03-24 10:00:00',
#       'date_end': '2018-03-24 17:00:00'},
#      {'session_count': '173',
#       'date_start': '2018-03-25 10:00:00',
#       'date_end': '2018-03-25 17:00:00'},
#      {'session_count': '174',
#       'date_start': '2018-03-26 10:00:00',
#       'date_end': '2018-03-26 17:00:00'},
#      {'session_count': '175',
#       'date_start': '2018-03-27 10:00:00',
#       'date_end': '2018-03-27 17:00:00'},
#      {'session_count': '176',
#       'date_start': '2018-03-28 10:00:00',
#       'date_end': '2018-03-28 17:00:00'},
#      {'session_count': '177',
#       'date_start': '2018-03-29 10:00:00',
#       'date_end': '2018-03-29 17:00:00'},
#      {'session_count': '178',
#       'date_start': '2018-03-31 10:00:00',
#       'date_end': '2018-03-31 17:00:00'},
#      {'session_count': '179',
#       'date_start': '2018-04-01 10:00:00',
#       'date_end': '2018-04-01 17:00:00'},
#      {'session_count': '180',
#       'date_start': '2018-04-02 10:00:00',
#       'date_end': '2018-04-02 17:00:00'},
#      {'session_count': '181',
#       'date_start': '2018-04-03 10:00:00',
#       'date_end': '2018-04-03 17:00:00'},
#      {'session_count': '182',
#       'date_start': '2018-04-04 10:00:00',
#       'date_end': '2018-04-04 17:00:00'},
#      {'session_count': '183',
#       'date_start': '2018-04-05 10:00:00',
#       'date_end': '2018-04-05 17:00:00'},
#      {'session_count': '184',
#       'date_start': '2018-04-06 10:00:00',
#       'date_end': '2018-04-06 17:00:00'},
#      {'session_count': '185',
#       'date_start': '2018-04-07 10:00:00',
#       'date_end': '2018-04-07 17:00:00'},
#      {'session_count': '186',
#       'date_start': '2018-04-08 10:00:00',
#       'date_end': '2018-04-08 17:00:00'},
#      {'session_count': '187',
#       'date_start': '2018-04-09 10:00:00',
#       'date_end': '2018-04-09 17:00:00'},
#      {'session_count': '188',
#       'date_start': '2018-04-10 10:00:00',
#       'date_end': '2018-04-10 17:00:00'},
#      {'session_count': '189',
#       'date_start': '2018-04-11 10:00:00',
#       'date_end': '2018-04-11 17:00:00'},
#      {'session_count': '190',
#       'date_start': '2018-04-12 10:00:00',
#       'date_end': '2018-04-12 17:00:00'},
#      {'session_count': '191',
#       'date_start': '2018-04-13 10:00:00',
#       'date_end': '2018-04-13 17:00:00'},
#      {'session_count': '192',
#       'date_start': '2018-04-14 10:00:00',
#       'date_end': '2018-04-14 17:00:00'},
#      {'session_count': '193',
#       'date_start': '2018-04-15 10:00:00',
#       'date_end': '2018-04-15 17:00:00'},
#      {'session_count': '194',
#       'date_start': '2018-04-16 10:00:00',
#       'date_end': '2018-04-16 17:00:00'},
#      {'session_count': '195',
#       'date_start': '2018-04-17 10:00:00',
#       'date_end': '2018-04-17 17:00:00'},
#      {'session_count': '196',
#       'date_start': '2018-04-18 10:00:00',
#       'date_end': '2018-04-18 17:00:00'},
#      {'session_count': '197',
#       'date_start': '2018-04-19 10:00:00',
#       'date_end': '2018-04-19 17:00:00'},
#      {'session_count': '198',
#       'date_start': '2018-04-20 10:00:00',
#       'date_end': '2018-04-20 17:00:00'},
#      {'session_count': '199',
#       'date_start': '2018-04-21 10:00:00',
#       'date_end': '2018-04-21 17:00:00'},
#      {'session_count': '200',
#       'date_start': '2018-04-22 10:00:00',
#       'date_end': '2018-04-22 17:00:00'},
#      {'session_count': '201',
#       'date_start': '2018-04-23 10:00:00',
#       'date_end': '2018-04-23 17:00:00'},
#      {'session_count': '202',
#       'date_start': '2018-04-24 10:00:00',
#       'date_end': '2018-04-24 17:00:00'},
#      {'session_count': '203',
#       'date_start': '2018-04-25 10:00:00',
#       'date_end': '2018-04-25 17:00:00'},
#      {'session_count': '204',
#       'date_start': '2018-04-26 10:00:00',
#       'date_end': '2018-04-26 17:00:00'},
#      {'session_count': '205',
#       'date_start': '2018-04-27 10:00:00',
#       'date_end': '2018-04-27 17:00:00'},
#      {'session_count': '206',
#       'date_start': '2018-04-28 10:00:00',
#       'date_end': '2018-04-28 17:00:00'},
#      {'session_count': '207',
#       'date_start': '2018-04-29 10:00:00',
#       'date_end': '2018-04-29 17:00:00'},
#      {'session_count': '208',
#       'date_start': '2018-04-30 10:00:00',
#       'date_end': '2018-04-30 17:00:00'},
#      {'session_count': '209',
#       'date_start': '2018-05-01 10:00:00',
#       'date_end': '2018-05-01 17:00:00'},
#      {'session_count': '210',
#       'date_start': '2018-05-02 10:00:00',
#       'date_end': '2018-05-02 17:00:00'},
#      {'session_count': '211',
#       'date_start': '2018-05-03 10:00:00',
#       'date_end': '2018-05-03 17:00:00'},
#      {'session_count': '212',
#       'date_start': '2018-05-04 10:00:00',
#       'date_end': '2018-05-04 17:00:00'},
#      {'session_count': '213',
#       'date_start': '2018-05-05 10:00:00',
#       'date_end': '2018-05-05 17:00:00'},
#      {'session_count': '214',
#       'date_start': '2018-05-06 10:00:00',
#       'date_end': '2018-05-06 17:00:00'},
#      {'session_count': '215',
#       'date_start': '2018-05-07 10:00:00',
#       'date_end': '2018-05-07 17:00:00'},
#      {'session_count': '216',
#       'date_start': '2018-05-08 10:00:00',
#       'date_end': '2018-05-08 17:00:00'},
#      {'session_count': '217',
#       'date_start': '2018-05-09 10:00:00',
#       'date_end': '2018-05-09 17:00:00'},
#      {'session_count': '218',
#       'date_start': '2018-05-10 10:00:00',
#       'date_end': '2018-05-10 17:00:00'},
#      {'session_count': '219',
#       'date_start': '2018-05-11 10:00:00',
#       'date_end': '2018-05-11 17:00:00'},
#      {'session_count': '220',
#       'date_start': '2018-05-12 10:00:00',
#       'date_end': '2018-05-12 17:00:00'},
#      {'session_count': '221',
#       'date_start': '2018-05-13 10:00:00',
#       'date_end': '2018-05-13 17:00:00'},
#      {'session_count': '222',
#       'date_start': '2018-05-14 10:00:00',
#       'date_end': '2018-05-14 17:00:00'},
#      {'session_count': '223',
#       'date_start': '2018-05-15 10:00:00',
#       'date_end': '2018-05-15 17:00:00'},
#      {'session_count': '224',
#       'date_start': '2018-05-16 10:00:00',
#       'date_end': '2018-05-16 17:00:00'},
#      {'session_count': '225',
#       'date_start': '2018-05-17 10:00:00',
#       'date_end': '2018-05-17 17:00:00'},
#      {'session_count': '226',
#       'date_start': '2018-05-18 10:00:00',
#       'date_end': '2018-05-18 17:00:00'},
#      {'session_count': '227',
#       'date_start': '2018-05-19 10:00:00',
#       'date_end': '2018-05-19 17:00:00'},
#      {'session_count': '228',
#       'date_start': '2018-05-20 10:00:00',
#       'date_end': '2018-05-20 17:00:00'},
#      {'session_count': '229',
#       'date_start': '2018-05-21 10:00:00',
#       'date_end': '2018-05-21 17:00:00'},
#      {'session_count': '230',
#       'date_start': '2018-05-22 10:00:00',
#       'date_end': '2018-05-22 17:00:00'},
#      {'session_count': '231',
#       'date_start': '2018-05-23 10:00:00',
#       'date_end': '2018-05-23 17:00:00'},
#      {'session_count': '232',
#       'date_start': '2018-05-24 10:00:00',
#       'date_end': '2018-05-24 17:00:00'},
#      {'session_count': '233',
#       'date_start': '2018-05-25 10:00:00',
#       'date_end': '2018-05-25 17:00:00'},
#      {'session_count': '234',
#       'date_start': '2018-05-26 10:00:00',
#       'date_end': '2018-05-26 17:00:00'},
#      {'session_count': '235',
#       'date_start': '2018-05-27 10:00:00',
#       'date_end': '2018-05-27 17:00:00'},
#      {'session_count': '236',
#       'date_start': '2018-05-28 10:00:00',
#       'date_end': '2018-05-28 17:00:00'},
#      {'session_count': '237',
#       'date_start': '2018-05-29 10:00:00',
#       'date_end': '2018-05-29 17:00:00'},
#      {'session_count': '238',
#       'date_start': '2018-05-30 10:00:00',
#       'date_end': '2018-05-30 17:00:00'},
#      {'session_count': '239',
#       'date_start': '2018-05-31 10:00:00',
#       'date_end': '2018-05-31 17:00:00'},
#      {'session_count': '240',
#       'date_start': '2018-06-01 10:00:00',
#       'date_end': '2018-06-01 17:00:00'},
#      {'session_count': '241',
#       'date_start': '2018-06-02 10:00:00',
#       'date_end': '2018-06-02 17:00:00'},
#      {'session_count': '242',
#       'date_start': '2018-06-03 10:00:00',
#       'date_end': '2018-06-03 17:00:00'},
#      {'session_count': '243',
#       'date_start': '2018-06-04 10:00:00',
#       'date_end': '2018-06-04 17:00:00'},
#      {'session_count': '244',
#       'date_start': '2018-06-05 10:00:00',
#       'date_end': '2018-06-05 17:00:00'},
#      {'session_count': '245',
#       'date_start': '2018-06-06 10:00:00',
#       'date_end': '2018-06-06 17:00:00'},
#      {'session_count': '246',
#       'date_start': '2018-06-07 10:00:00',
#       'date_end': '2018-06-07 17:00:00'},
#      {'session_count': '247',
#       'date_start': '2018-06-08 10:00:00',
#       'date_end': '2018-06-08 17:00:00'},
#      {'session_count': '248',
#       'date_start': '2018-06-09 10:00:00',
#       'date_end': '2018-06-09 17:00:00'},
#      {'session_count': '249',
#       'date_start': '2018-06-10 10:00:00',
#       'date_end': '2018-06-10 17:00:00'},
#      {'session_count': '250',
#       'date_start': '2018-06-11 10:00:00',
#       'date_end': '2018-06-11 17:00:00'},
#      {'session_count': '251',
#       'date_start': '2018-06-12 10:00:00',
#       'date_end': '2018-06-12 17:00:00'},
#      {'session_count': '252',
#       'date_start': '2018-06-13 10:00:00',
#       'date_end': '2018-06-13 17:00:00'},
#      {'session_count': '253',
#       'date_start': '2018-06-14 10:00:00',
#       'date_end': '2018-06-14 17:00:00'},
#      {'session_count': '254',
#       'date_start': '2018-06-15 10:00:00',
#       'date_end': '2018-06-15 17:00:00'},
#      {'session_count': '255',
#       'date_start': '2018-06-16 10:00:00',
#       'date_end': '2018-06-16 17:00:00'},
#      {'session_count': '256',
#       'date_start': '2018-06-17 10:00:00',
#       'date_end': '2018-06-17 17:00:00'},
#      {'session_count': '257',
#       'date_start': '2018-06-18 10:00:00',
#       'date_end': '2018-06-18 17:00:00'},
#      {'session_count': '258',
#       'date_start': '2018-06-19 10:00:00',
#       'date_end': '2018-06-19 17:00:00'},
#      {'session_count': '259',
#       'date_start': '2018-06-20 10:00:00',
#       'date_end': '2018-06-20 17:00:00'},
#      {'session_count': '260',
#       'date_start': '2018-06-21 10:00:00',
#       'date_end': '2018-06-21 17:00:00'},
#      {'session_count': '261',
#       'date_start': '2018-06-22 10:00:00',
#       'date_end': '2018-06-22 17:00:00'},
#      {'session_count': '262',
#       'date_start': '2018-06-23 10:00:00',
#       'date_end': '2018-06-23 17:00:00'},
#      {'session_count': '263',
#       'date_start': '2018-06-24 10:00:00',
#       'date_end': '2018-06-24 17:00:00'},
#      {'session_count': '264',
#       'date_start': '2018-06-25 10:00:00',
#       'date_end': '2018-06-25 17:00:00'},
#      {'session_count': '265',
#       'date_start': '2018-06-26 10:00:00',
#       'date_end': '2018-06-26 17:00:00'},
#      {'session_count': '266',
#       'date_start': '2018-06-27 10:00:00',
#       'date_end': '2018-06-27 17:00:00'},
#      {'session_count': '267',
#       'date_start': '2018-06-28 10:00:00',
#       'date_end': '2018-06-28 17:00:00'},
#      {'session_count': '268',
#       'date_start': '2018-06-29 10:00:00',
#       'date_end': '2018-06-29 17:00:00'},
#      {'session_count': '269',
#       'date_start': '2018-06-30 10:00:00',
#       'date_end': '2018-06-30 17:00:00'},
#      {'session_count': '270',
#       'date_start': '2018-07-01 10:00:00',
#       'date_end': '2018-07-01 17:00:00'},
#      {'session_count': '271',
#       'date_start': '2018-07-02 10:00:00',
#       'date_end': '2018-07-02 17:00:00'},
#      {'session_count': '272',
#       'date_start': '2018-07-03 10:00:00',
#       'date_end': '2018-07-03 17:00:00'},
#      {'session_count': '273',
#       'date_start': '2018-07-04 10:00:00',
#       'date_end': '2018-07-04 17:00:00'},
#      {'session_count': '274',
#       'date_start': '2018-07-05 10:00:00',
#       'date_end': '2018-07-05 17:00:00'},
#      {'session_count': '275',
#       'date_start': '2018-07-06 10:00:00',
#       'date_end': '2018-07-06 17:00:00'},
#      {'session_count': '276',
#       'date_start': '2018-07-07 10:00:00',
#       'date_end': '2018-07-07 17:00:00'},
#      {'session_count': '277',
#       'date_start': '2018-07-08 10:00:00',
#       'date_end': '2018-07-08 17:00:00'},
#      {'session_count': '278',
#       'date_start': '2018-07-09 10:00:00',
#       'date_end': '2018-07-09 17:00:00'},
#      {'session_count': '279',
#       'date_start': '2018-07-10 10:00:00',
#       'date_end': '2018-07-10 17:00:00'},
#      {'session_count': '280',
#       'date_start': '2018-07-11 10:00:00',
#       'date_end': '2018-07-11 17:00:00'},
#      {'session_count': '281',
#       'date_start': '2018-07-12 10:00:00',
#       'date_end': '2018-07-12 17:00:00'},
#      {'session_count': '282',
#       'date_start': '2018-07-13 10:00:00',
#       'date_end': '2018-07-13 17:00:00'},
#      {'session_count': '283',
#       'date_start': '2018-07-14 10:00:00',
#       'date_end': '2018-07-14 17:00:00'},
#      {'session_count': '284',
#       'date_start': '2018-07-15 10:00:00',
#       'date_end': '2018-07-15 17:00:00'},
#      {'session_count': '285',
#       'date_start': '2018-07-16 10:00:00',
#       'date_end': '2018-07-16 17:00:00'},
#      {'session_count': '286',
#       'date_start': '2018-07-17 10:00:00',
#       'date_end': '2018-07-17 17:00:00'},
#      {'session_count': '287',
#       'date_start': '2018-07-18 10:00:00',
#       'date_end': '2018-07-18 17:00:00'},
#      {'session_count': '288',
#       'date_start': '2018-07-19 10:00:00',
#       'date_end': '2018-07-19 17:00:00'},
#      {'session_count': '289',
#       'date_start': '2018-07-20 10:00:00',
#       'date_end': '2018-07-20 17:00:00'},
#      {'session_count': '290',
#       'date_start': '2018-07-21 10:00:00',
#       'date_end': '2018-07-21 17:00:00'},
#      {'session_count': '291',
#       'date_start': '2018-07-22 10:00:00',
#       'date_end': '2018-07-22 17:00:00'},
#      {'session_count': '292',
#       'date_start': '2018-07-23 10:00:00',
#       'date_end': '2018-07-23 17:00:00'},
#      {'session_count': '293',
#       'date_start': '2018-07-24 10:00:00',
#       'date_end': '2018-07-24 17:00:00'},
#      {'session_count': '294',
#       'date_start': '2018-07-25 10:00:00',
#       'date_end': '2018-07-25 17:00:00'},
#      {'session_count': '295',
#       'date_start': '2018-07-26 10:00:00',
#       'date_end': '2018-07-26 17:00:00'},
#      {'session_count': '296',
#       'date_start': '2018-07-27 10:00:00',
#       'date_end': '2018-07-27 17:00:00'},
#      {'session_count': '297',
#       'date_start': '2018-07-28 10:00:00',
#       'date_end': '2018-07-28 17:00:00'},
#      {'session_count': '298',
#       'date_start': '2018-07-29 10:00:00',
#       'date_end': '2018-07-29 17:00:00'},
#      {'session_count': '299',
#       'date_start': '2018-07-30 10:00:00',
#       'date_end': '2018-07-30 17:00:00'},
#      {'session_count': '300',
#       'date_start': '2018-07-31 10:00:00',
#       'date_end': '2018-07-31 17:00:00'},
#      {'session_count': '301',
#       'date_start': '2018-08-01 10:00:00',
#       'date_end': '2018-08-01 17:00:00'},
#      {'session_count': '302',
#       'date_start': '2018-08-02 10:00:00',
#       'date_end': '2018-08-02 17:00:00'},
#      {'session_count': '303',
#       'date_start': '2018-08-03 10:00:00',
#       'date_end': '2018-08-03 17:00:00'},
#      {'session_count': '304',
#       'date_start': '2018-08-04 10:00:00',
#       'date_end': '2018-08-04 17:00:00'},
#      {'session_count': '305',
#       'date_start': '2018-08-05 10:00:00',
#       'date_end': '2018-08-05 17:00:00'},
#      {'session_count': '306',
#       'date_start': '2018-08-06 10:00:00',
#       'date_end': '2018-08-06 17:00:00'},
#      {'session_count': '307',
#       'date_start': '2018-08-07 10:00:00',
#       'date_end': '2018-08-07 17:00:00'},
#      {'session_count': '308',
#       'date_start': '2018-08-08 10:00:00',
#       'date_end': '2018-08-08 17:00:00'},
#      {'session_count': '309',
#       'date_start': '2018-08-09 10:00:00',
#       'date_end': '2018-08-09 17:00:00'},
#      {'session_count': '310',
#       'date_start': '2018-08-10 10:00:00',
#       'date_end': '2018-08-10 17:00:00'},
#      {'session_count': '311',
#       'date_start': '2018-08-11 10:00:00',
#       'date_end': '2018-08-11 17:00:00'},
#      {'session_count': '312',
#       'date_start': '2018-08-12 10:00:00',
#       'date_end': '2018-08-12 17:00:00'},
#      {'session_count': '313',
#       'date_start': '2018-08-13 10:00:00',
#       'date_end': '2018-08-13 17:00:00'},
#      {'session_count': '314',
#       'date_start': '2018-08-14 10:00:00',
#       'date_end': '2018-08-14 17:00:00'},
#      {'session_count': '315',
#       'date_start': '2018-08-15 10:00:00',
#       'date_end': '2018-08-15 17:00:00'},
#      {'session_count': '316',
#       'date_start': '2018-08-16 10:00:00',
#       'date_end': '2018-08-16 17:00:00'},
#      {'session_count': '317',
#       'date_start': '2018-08-17 10:00:00',
#       'date_end': '2018-08-17 17:00:00'},
#      {'session_count': '318',
#       'date_start': '2018-08-18 10:00:00',
#       'date_end': '2018-08-18 17:00:00'},
#      {'session_count': '319',
#       'date_start': '2018-08-19 10:00:00',
#       'date_end': '2018-08-19 17:00:00'},
#      {'session_count': '320',
#       'date_start': '2018-08-20 10:00:00',
#       'date_end': '2018-08-20 17:00:00'},
#      {'session_count': '321',
#       'date_start': '2018-08-21 10:00:00',
#       'date_end': '2018-08-21 17:00:00'},
#      {'session_count': '322',
#       'date_start': '2018-08-22 10:00:00',
#       'date_end': '2018-08-22 17:00:00'},
#      {'session_count': '323',
#       'date_start': '2018-08-23 10:00:00',
#       'date_end': '2018-08-23 17:00:00'},
#      {'session_count': '324',
#       'date_start': '2018-08-24 10:00:00',
#       'date_end': '2018-08-24 17:00:00'},
#      {'session_count': '325',
#       'date_start': '2018-08-25 10:00:00',
#       'date_end': '2018-08-25 17:00:00'},
#      {'session_count': '326',
#       'date_start': '2018-08-26 10:00:00',
#       'date_end': '2018-08-26 17:00:00'},
#      {'session_count': '327',
#       'date_start': '2018-08-27 10:00:00',
#       'date_end': '2018-08-27 17:00:00'},
#      {'session_count': '328',
#       'date_start': '2018-08-28 10:00:00',
#       'date_end': '2018-08-28 17:00:00'},
#      {'session_count': '329',
#       'date_start': '2018-08-29 10:00:00',
#       'date_end': '2018-08-29 17:00:00'},
#      {'session_count': '330',
#       'date_start': '2018-08-30 10:00:00',
#       'date_end': '2018-08-30 17:00:00'},
#      {'session_count': '331',
#       'date_start': '2018-08-31 10:00:00',
#       'date_end': '2018-08-31 17:00:00'},
#      {'session_count': '332',
#       'date_start': '2018-09-01 10:00:00',
#       'date_end': '2018-09-01 17:00:00'},
#      {'session_count': '333',
#       'date_start': '2018-09-02 10:00:00',
#       'date_end': '2018-09-02 17:00:00'},
#      {'session_count': '334',
#       'date_start': '2018-09-03 10:00:00',
#       'date_end': '2018-09-03 17:00:00'},
#      {'session_count': '335',
#       'date_start': '2018-09-04 10:00:00',
#       'date_end': '2018-09-04 17:00:00'},
#      {'session_count': '336',
#       'date_start': '2018-09-05 10:00:00',
#       'date_end': '2018-09-05 17:00:00'},
#      {'session_count': '337',
#       'date_start': '2018-09-06 10:00:00',
#       'date_end': '2018-09-06 17:00:00'},
#      {'session_count': '338',
#       'date_start': '2018-09-07 10:00:00',
#       'date_end': '2018-09-07 17:00:00'},
#      {'session_count': '339',
#       'date_start': '2018-09-08 10:00:00',
#       'date_end': '2018-09-08 17:00:00'},
#      {'session_count': '340',
#       'date_start': '2018-09-09 10:00:00',
#       'date_end': '2018-09-09 17:00:00'},
#      {'session_count': '341',
#       'date_start': '2018-09-10 10:00:00',
#       'date_end': '2018-09-10 17:00:00'},
#      {'session_count': '342',
#       'date_start': '2018-09-11 10:00:00',
#       'date_end': '2018-09-11 17:00:00'},
#      {'session_count': '343',
#       'date_start': '2018-09-12 10:00:00',
#       'date_end': '2018-09-12 17:00:00'},
#      {'session_count': '344',
#       'date_start': '2018-09-13 10:00:00',
#       'date_end': '2018-09-13 17:00:00'},
#      {'session_count': '345',
#       'date_start': '2018-09-14 10:00:00',
#       'date_end': '2018-09-14 17:00:00'},
#      {'session_count': '346',
#       'date_start': '2018-09-15 10:00:00',
#       'date_end': '2018-09-15 17:00:00'},
#      {'session_count': '347',
#       'date_start': '2018-09-16 10:00:00',
#       'date_end': '2018-09-16 17:00:00'},
#      {'session_count': '348',
#       'date_start': '2018-09-17 10:00:00',
#       'date_end': '2018-09-17 17:00:00'},
#      {'session_count': '349',
#       'date_start': '2018-09-18 10:00:00',
#       'date_end': '2018-09-18 17:00:00'},
#      {'session_count': '350',
#       'date_start': '2018-09-19 10:00:00',
#       'date_end': '2018-09-19 17:00:00'},
#      {'session_count': '351',
#       'date_start': '2018-09-20 10:00:00',
#       'date_end': '2018-09-20 17:00:00'},
#      {'session_count': '352',
#       'date_start': '2018-09-21 10:00:00',
#       'date_end': '2018-09-21 17:00:00'},
#      {'session_count': '353',
#       'date_start': '2018-09-22 10:00:00',
#       'date_end': '2018-09-22 17:00:00'},
#      {'session_count': '354',
#       'date_start': '2018-09-23 10:00:00',
#       'date_end': '2018-09-23 17:00:00'},
#      {'session_count': '355',
#       'date_start': '2018-09-24 10:00:00',
#       'date_end': '2018-09-24 17:00:00'},
#      {'session_count': '356',
#       'date_start': '2018-09-25 10:00:00',
#       'date_end': '2018-09-25 17:00:00'},
#      {'session_count': '357',
#       'date_start': '2018-09-26 10:00:00',
#       'date_end': '2018-09-26 17:00:00'},
#      {'session_count': '358',
#       'date_start': '2018-09-27 10:00:00',
#       'date_end': '2018-09-27 17:00:00'},
#      {'session_count': '359',
#       'date_start': '2018-09-28 10:00:00',
#       'date_end': '2018-09-28 17:00:00'},
#      {'session_count': '360',
#       'date_start': '2018-09-29 10:00:00',
#       'date_end': '2018-09-29 17:00:00'},
#      {'session_count': '361',
#       'date_start': '2018-09-30 10:00:00',
#       'date_end': '2018-09-30 17:00:00'},
#      {'session_count': '362',
#       'date_start': '2018-10-01 10:00:00',
#       'date_end': '2018-10-01 17:00:00'},
#      {'session_count': '363',
#       'date_start': '2018-10-02 10:00:00',
#       'date_end': '2018-10-02 17:00:00'},
#      {'session_count': '364',
#       'date_start': '2018-10-03 10:00:00',
#       'date_end': '2018-10-03 17:00:00'},
#      {'session_count': '365',
#       'date_start': '2018-10-04 10:00:00',
#       'date_end': '2018-10-04 17:00:00'},
#      {'session_count': '366',
#       'date_start': '2018-10-05 10:00:00',
#       'date_end': '2018-10-05 17:00:00'},
#      {'session_count': '367',
#       'date_start': '2018-10-06 10:00:00',
#       'date_end': '2018-10-06 17:00:00'},
#      {'session_count': '368',
#       'date_start': '2018-10-07 10:00:00',
#       'date_end': '2018-10-07 17:00:00'},
#      {'session_count': '369',
#       'date_start': '2018-10-08 10:00:00',
#       'date_end': '2018-10-08 17:00:00'},
#      {'session_count': '370',
#       'date_start': '2018-10-09 10:00:00',
#       'date_end': '2018-10-09 17:00:00'},
#      {'session_count': '371',
#       'date_start': '2018-10-10 10:00:00',
#       'date_end': '2018-10-10 17:00:00'},
#      {'session_count': '372',
#       'date_start': '2018-10-11 10:00:00',
#       'date_end': '2018-10-11 17:00:00'},
#      {'session_count': '373',
#       'date_start': '2018-10-12 10:00:00',
#       'date_end': '2018-10-12 17:00:00'},
#      {'session_count': '374',
#       'date_start': '2018-10-13 10:00:00',
#       'date_end': '2018-10-13 17:00:00'},
#      {'session_count': '375',
#       'date_start': '2018-10-14 10:00:00',
#       'date_end': '2018-10-14 17:00:00'},
#      {'session_count': '376',
#       'date_start': '2018-10-15 10:00:00',
#       'date_end': '2018-10-15 17:00:00'},
#      {'session_count': '377',
#       'date_start': '2018-10-16 10:00:00',
#       'date_end': '2018-10-16 17:00:00'},
#      {'session_count': '378',
#       'date_start': '2018-10-17 10:00:00',
#       'date_end': '2018-10-17 17:00:00'},
#      {'session_count': '379',
#       'date_start': '2018-10-18 10:00:00',
#       'date_end': '2018-10-18 17:00:00'},
#      {'session_count': '380',
#       'date_start': '2018-10-19 10:00:00',
#       'date_end': '2018-10-19 17:00:00'},
#      {'session_count': '381',
#       'date_start': '2018-10-20 10:00:00',
#       'date_end': '2018-10-20 17:00:00'},
#      {'session_count': '382',
#       'date_start': '2018-10-21 10:00:00',
#       'date_end': '2018-10-21 17:00:00'},
#      {'session_count': '383',
#       'date_start': '2018-10-22 10:00:00',
#       'date_end': '2018-10-22 17:00:00'},
#      {'session_count': '384',
#       'date_start': '2018-10-23 10:00:00',
#       'date_end': '2018-10-23 17:00:00'},
#      {'session_count': '385',
#       'date_start': '2018-10-24 10:00:00',
#       'date_end': '2018-10-24 17:00:00'},
#      {'session_count': '386',
#       'date_start': '2018-10-25 10:00:00',
#       'date_end': '2018-10-25 17:00:00'},
#      {'session_count': '387',
#       'date_start': '2018-10-26 10:00:00',
#       'date_end': '2018-10-26 17:00:00'},
#      {'session_count': '388',
#       'date_start': '2018-10-27 10:00:00',
#       'date_end': '2018-10-27 17:00:00'},
#      {'session_count': '389',
#       'date_start': '2018-10-28 10:00:00',
#       'date_end': '2018-10-28 17:00:00'},
#      {'session_count': '390',
#       'date_start': '2018-10-29 10:00:00',
#       'date_end': '2018-10-29 17:00:00'},
#      {'session_count': '391',
#       'date_start': '2018-10-30 10:00:00',
#       'date_end': '2018-10-30 17:00:00'},
#      {'session_count': '392',
#       'date_start': '2018-10-31 10:00:00',
#       'date_end': '2018-10-31 17:00:00'},
#      {'session_count': '393',
#       'date_start': '2018-11-01 10:00:00',
#       'date_end': '2018-11-01 17:00:00'},
#      {'session_count': '394',
#       'date_start': '2018-11-02 10:00:00',
#       'date_end': '2018-11-02 17:00:00'},
#      {'session_count': '395',
#       'date_start': '2018-11-03 10:00:00',
#       'date_end': '2018-11-03 17:00:00'},
#      {'session_count': '396',
#       'date_start': '2018-11-04 10:00:00',
#       'date_end': '2018-11-04 17:00:00'},
#      {'session_count': '397',
#       'date_start': '2018-11-05 10:00:00',
#       'date_end': '2018-11-05 17:00:00'},
#      {'session_count': '398',
#       'date_start': '2018-11-06 10:00:00',
#       'date_end': '2018-11-06 17:00:00'},
#      {'session_count': '399',
#       'date_start': '2018-11-07 10:00:00',
#       'date_end': '2018-11-07 17:00:00'},
#      {'session_count': '400',
#       'date_start': '2018-11-08 10:00:00',
#       'date_end': '2018-11-08 17:00:00'},
#      {'session_count': '401',
#       'date_start': '2018-11-09 10:00:00',
#       'date_end': '2018-11-09 17:00:00'},
#      {'session_count': '402',
#       'date_start': '2018-11-10 10:00:00',
#       'date_end': '2018-11-10 17:00:00'},
#      {'session_count': '403',
#       'date_start': '2018-11-11 10:00:00',
#       'date_end': '2018-11-11 17:00:00'},
#      {'session_count': '404',
#       'date_start': '2018-11-12 10:00:00',
#       'date_end': '2018-11-12 17:00:00'},
#      {'session_count': '405',
#       'date_start': '2018-11-13 10:00:00',
#       'date_end': '2018-11-13 17:00:00'},
#      {'session_count': '406',
#       'date_start': '2018-11-14 10:00:00',
#       'date_end': '2018-11-14 17:00:00'},
#      {'session_count': '407',
#       'date_start': '2018-11-15 10:00:00',
#       'date_end': '2018-11-15 17:00:00'},
#      {'session_count': '408',
#       'date_start': '2018-11-16 10:00:00',
#       'date_end': '2018-11-16 17:00:00'},
#      {'session_count': '409',
#       'date_start': '2018-11-17 10:00:00',
# ...
#      {'date_start': '2020-04-27 10:00:00', 'date_end': '2020-04-27 17:00:00'},
#      {'date_start': '2020-04-28 10:00:00', 'date_end': '2020-04-28 17:00:00'},
#      {'date_start': '2020-04-29 10:00:00', 'date_end': '2020-04-29 17:00:00'},
#      {'date_start': '2020-04-30 10:00:00', 'date_end': '2020-04-30 17:00:00'},
#      {'date_start': '2020-05-01 10:00:00', 'date_end': '2020-05-01 17:00:00'},
#      {'date_start': '2020-05-02 10:00:00', 'date_end': '2020-05-02 17:00:00'},
#      {'date_start': '2020-05-03 10:00:00', 'date_end': '2020-05-03 17:00:00'},
#      {'date_start': '2020-05-04 10:00:00', 'date_end': '2020-05-04 17:00:00'},
#      {'date_start': '2020-05-05 10:00:00', 'date_end': '2020-05-05 17:00:00'},
#      {'date_start': '2020-05-06 10:00:00', 'date_end': '2020-05-06 17:00:00'},
#      {'date_start': '2020-05-07 10:00:00', 'date_end': '2020-05-07 17:00:00'},
#      {'date_start': '2020-05-08 10:00:00', 'date_end': '2020-05-08 17:00:00'},
#      {'date_start': '2020-05-09 10:00:00', 'date_end': '2020-05-09 17:00:00'},
#      {'date_start': '2020-05-10 10:00:00', 'date_end': '2020-05-10 17:00:00'},
#      {'date_start': '2020-05-11 10:00:00', 'date_end': '2020-05-11 17:00:00'},
#      {'date_start': '2020-05-12 10:00:00', 'date_end': '2020-05-12 17:00:00'},
#      {'date_start': '2020-05-13 10:00:00', 'date_end': '2020-05-13 17:00:00'},
#      {'date_start': '2020-05-14 10:00:00', 'date_end': '2020-05-14 17:00:00'},
#      {'date_start': '2020-05-15 10:00:00', 'date_end': '2020-05-15 17:00:00'},
#      {'date_start': '2020-05-16 10:00:00', 'date_end': '2020-05-16 17:00:00'},
#      {'date_start': '2020-05-17 10:00:00', 'date_end': '2020-05-17 17:00:00'},
#      {'date_start': '2020-05-18 10:00:00', 'date_end': '2020-05-18 17:00:00'},
#      {'date_start': '2020-05-19 10:00:00', 'date_end': '2020-05-19 17:00:00'},
#      {'date_start': '2020-05-20 10:00:00', 'date_end': '2020-05-20 17:00:00'},
#      {'date_start': '2020-05-21 10:00:00', 'date_end': '2020-05-21 17:00:00'},
#      {'date_start': '2020-05-22 10:00:00', 'date_end': '2020-05-22 17:00:00'},
#      {'date_start': '2020-05-23 10:00:00', 'date_end': '2020-05-23 17:00:00'},
#      {'date_start': '2020-05-24 10:00:00', 'date_end': '2020-05-24 17:00:00'},
#      {'date_start': '2020-05-25 10:00:00', 'date_end': '2020-05-25 17:00:00'},
#      {'date_start': '2020-05-26 10:00:00', 'date_end': '2020-05-26 17:00:00'},
#      {'date_start': '2020-05-27 10:00:00', 'date_end': '2020-05-27 17:00:00'},
#      {'date_start': '2020-05-28 10:00:00', 'date_end': '2020-05-28 17:00:00'},
#      {'date_start': '2020-05-29 10:00:00', 'date_end': '2020-05-29 17:00:00'},
#      {'date_start': '2020-05-30 10:00:00', 'date_end': '2020-05-30 17:00:00'},
#      {'date_start': '2020-05-31 10:00:00', 'date_end': '2020-05-31 17:00:00'},
#      {'date_start': '2020-06-01 10:00:00', 'date_end': '2020-06-01 17:00:00'},
#      {'date_start': '2020-06-02 10:00:00', 'date_end': '2020-06-02 17:00:00'},
#      {'date_start': '2020-06-03 10:00:00', 'date_end': '2020-06-03 17:00:00'},
#      {'date_start': '2020-06-04 10:00:00', 'date_end': '2020-06-04 17:00:00'},
#      {'date_start': '2020-06-05 10:00:00', 'date_end': '2020-06-05 17:00:00'},
#      {'date_start': '2020-06-06 10:00:00', 'date_end': '2020-06-06 17:00:00'},
#      {'date_start': '2020-06-07 10:00:00', 'date_end': '2020-06-07 17:00:00'},
#      {'date_start': '2020-06-08 10:00:00', 'date_end': '2020-06-08 17:00:00'},
#      {'date_start': '2020-06-09 10:00:00', 'date_end': '2020-06-09 17:00:00'},
#      {'date_start': '2020-06-10 10:00:00', 'date_end': '2020-06-10 17:00:00'},
#      {'date_start': '2020-06-11 10:00:00', 'date_end': '2020-06-11 17:00:00'},
#      {'date_start': '2020-06-12 10:00:00', 'date_end': '2020-06-12 17:00:00'},
#      {'date_start': '2020-06-13 10:00:00', 'date_end': '2020-06-13 17:00:00'},
#      {'date_start': '2020-06-14 10:00:00', 'date_end': '2020-06-14 17:00:00'},
#      {'date_start': '2020-06-15 10:00:00', 'date_end': '2020-06-15 17:00:00'},
#      {'date_start': '2020-06-16 10:00:00', 'date_end': '2020-06-16 17:00:00'},
#      {'date_start': '2020-06-17 10:00:00', 'date_end': '2020-06-17 17:00:00'},
#      {'date_start': '2020-06-18 10:00:00', 'date_end': '2020-06-18 17:00:00'},
#      {'date_start': '2020-06-19 10:00:00', 'date_end': '2020-06-19 17:00:00'},
#      {'date_start': '2020-06-20 10:00:00', 'date_end': '2020-06-20 17:00:00'},
#      {'date_start': '2020-06-22 10:00:00', 'date_end': '2020-06-22 17:00:00'},
#      {'date_start': '2020-06-23 10:00:00', 'date_end': '2020-06-23 17:00:00'},
#      {'date_start': '2020-06-24 10:00:00', 'date_end': '2020-06-24 17:00:00'},
#      {'date_start': '2020-06-25 10:00:00', 'date_end': '2020-06-25 17:00:00'},
#      {'date_start': '2020-06-26 10:00:00', 'date_end': '2020-06-26 17:00:00'},
#      {'date_start': '2020-06-27 10:00:00', 'date_end': '2020-06-27 17:00:00'},
#      {'date_start': '2020-06-28 10:00:00', 'date_end': '2020-06-28 17:00:00'},
#      {'date_start': '2020-06-29 10:00:00', 'date_end': '2020-06-29 17:00:00'},
#      {'date_start': '2020-06-30 10:00:00', 'date_end': '2020-06-30 17:00:00'},
#      {'date_start': '2020-07-01 10:00:00', 'date_end': '2020-07-01 17:00:00'},
#      {'date_start': '2020-07-02 10:00:00', 'date_end': '2020-07-02 17:00:00'},
#      {'date_start': '2020-07-03 10:00:00', 'date_end': '2020-07-03 17:00:00'},
#      {'date_start': '2020-07-04 10:00:00', 'date_end': '2020-07-04 17:00:00'},
#      {'date_start': '2020-07-05 10:00:00', 'date_end': '2020-07-05 17:00:00'},
#      {'date_start': '2020-07-06 10:00:00', 'date_end': '2020-07-06 17:00:00'},
#      {'date_start': '2020-07-07 10:00:00', 'date_end': '2020-07-07 17:00:00'},
#      {'date_start': '2020-07-08 10:00:00', 'date_end': '2020-07-08 17:00:00'},
#      {'date_start': '2020-07-09 10:00:00', 'date_end': '2020-07-09 17:00:00'},
#      {'date_start': '2020-07-10 10:00:00', 'date_end': '2020-07-10 17:00:00'},
#      {'date_start': '2020-07-11 10:00:00', 'date_end': '2020-07-11 17:00:00'},
#      {'date_start': '2020-07-12 10:00:00', 'date_end': '2020-07-12 17:00:00'},
#      {'date_start': '2020-07-13 10:00:00', 'date_end': '2020-07-13 17:00:00'},
#      {'date_start': '2020-07-14 10:00:00', 'date_end': '2020-07-14 17:00:00'},
#      {'date_start': '2020-07-15 10:00:00', 'date_end': '2020-07-15 17:00:00'},
#      {'date_start': '2020-07-16 10:00:00', 'date_end': '2020-07-16 17:00:00'},
#      {'date_start': '2020-07-17 10:00:00', 'date_end': '2020-07-17 17:00:00'},
#      {'date_start': '2020-07-18 10:00:00', 'date_end': '2020-07-18 17:00:00'},
#      {'date_start': '2020-07-19 10:00:00', 'date_end': '2020-07-19 17:00:00'},
#      {'date_start': '2020-07-20 10:00:00', 'date_end': '2020-07-20 17:00:00'},
#      {'date_start': '2020-08-09 10:00:00', 'date_end': '2020-08-09 17:00:00'},
#      {'date_start': '2020-08-25 10:00:00',
#       'date_end': '2020-08-25 17:00:00'}]},
#    {'id': '175433',
#     'title': 'Snapshots Tour',
#     'description': 'Join one of our passionate Volunteer Guides for a 10 minute look at International Art from the QAGOMA Collection. This short tour is an ideal way to engage with art if you are limited by time.',
#     'start_time': '2019-01-02 12:00:00',
#     'end_time': '2019-04-18 12:10:00',
#     'stop_date': '2019-04-18',
#     'thumbnail': 'https://www.qagoma.qld.gov.au/__data/assets/image/0006/155562/Picasso_Maryanne_Dec2017_app.jpg',
#     'location': 'QAG: Melbourne St entrance',
#     'entry': 'Free',
#     'available': 'Yes',
#     'category': 'Tour',
#     'link': 'https://www.qagoma.qld.gov.au/whats-on/calendar/events/snapshots-tour2',
#     'sessions': [{'date_start': '2019-01-02 12:00:00',
#       'date_end': '2019-01-02 12:10:00'},
#      {'date_start': '2019-01-03 12:00:00', 'date_end': '2019-01-03 12:10:00'},
#      {'date_start': '2019-01-04 12:00:00', 'date_end': '2019-01-04 12:10:00'},
#      {'date_start': '2019-01-05 12:00:00', 'date_end': '2019-01-05 12:10:00'},
#      {'date_start': '2019-01-06 12:00:00', 'date_end': '2019-01-06 12:10:00'},
#      {'date_start': '2019-01-07 12:00:00', 'date_end': '2019-01-07 12:10:00'},
#      {'date_start': '2019-01-08 12:00:00', 'date_end': '2019-01-08 12:10:00'},
#      {'date_start': '2019-01-09 12:00:00', 'date_end': '2019-01-09 12:10:00'},
#      {'date_start': '2019-01-10 12:00:00', 'date_end': '2019-01-10 12:10:00'},
#      {'date_start': '2019-01-11 12:00:00', 'date_end': '2019-01-11 12:10:00'},
#      {'date_start': '2019-01-12 12:00:00', 'date_end': '2019-01-12 12:10:00'},
#      {'date_start': '2019-01-13 12:00:00', 'date_end': '2019-01-13 12:10:00'},
#      {'date_start': '2019-01-14 12:00:00', 'date_end': '2019-01-14 12:10:00'},
#      {'date_start': '2019-01-15 12:00:00', 'date_end': '2019-01-15 12:10:00'},
#      {'date_start': '2019-01-16 12:00:00', 'date_end': '2019-01-16 12:10:00'},
#      {'date_start': '2019-01-17 12:00:00', 'date_end': '2019-01-17 12:10:00'},
#      {'date_start': '2019-01-18 12:00:00', 'date_end': '2019-01-18 12:10:00'},
#      {'date_start': '2019-01-19 12:00:00', 'date_end': '2019-01-19 12:10:00'},
#      {'date_start': '2019-01-20 12:00:00', 'date_end': '2019-01-20 12:10:00'},
#      {'date_start': '2019-01-21 12:00:00', 'date_end': '2019-01-21 12:10:00'},
#      {'date_start': '2019-01-22 12:00:00', 'date_end': '2019-01-22 12:10:00'},
#      {'date_start': '2019-01-23 12:00:00', 'date_end': '2019-01-23 12:10:00'},
#      {'date_start': '2019-01-24 12:00:00', 'date_end': '2019-01-24 12:10:00'},
#      {'date_start': '2019-01-25 12:00:00', 'date_end': '2019-01-25 12:10:00'},
#      {'date_start': '2019-01-26 12:00:00', 'date_end': '2019-01-26 12:10:00'},
#      {'date_start': '2019-01-27 12:00:00', 'date_end': '2019-01-27 12:10:00'},
#      {'date_start': '2019-01-28 12:00:00', 'date_end': '2019-01-28 12:10:00'},
#      {'date_start': '2019-01-29 12:00:00', 'date_end': '2019-01-29 12:10:00'},
#      {'date_start': '2019-01-30 12:00:00', 'date_end': '2019-01-30 12:10:00'},
#      {'date_start': '2019-01-31 12:00:00', 'date_end': '2019-01-31 12:10:00'},
#      {'date_start': '2019-02-01 12:00:00', 'date_end': '2019-02-01 12:10:00'},
#      {'date_start': '2019-02-02 12:00:00', 'date_end': '2019-02-02 12:10:00'},
#      {'date_start': '2019-02-03 12:00:00', 'date_end': '2019-02-03 12:10:00'},
#      {'date_start': '2019-02-04 12:00:00', 'date_end': '2019-02-04 12:10:00'},
#      {'date_start': '2019-02-05 12:00:00', 'date_end': '2019-02-05 12:10:00'},
#      {'date_start': '2019-02-06 12:00:00', 'date_end': '2019-02-06 12:10:00'},
#      {'date_start': '2019-02-07 12:00:00', 'date_end': '2019-02-07 12:10:00'},
#      {'date_start': '2019-02-08 12:00:00', 'date_end': '2019-02-08 12:10:00'},
#      {'date_start': '2019-02-09 12:00:00', 'date_end': '2019-02-09 12:10:00'},
#      {'date_start': '2019-02-10 12:00:00', 'date_end': '2019-02-10 12:10:00'},
#      {'date_start': '2019-02-11 12:00:00', 'date_end': '2019-02-11 12:10:00'},
#      {'date_start': '2019-02-12 12:00:00', 'date_end': '2019-02-12 12:10:00'},
#      {'date_start': '2019-02-13 12:00:00', 'date_end': '2019-02-13 12:10:00'},
#      {'date_start': '2019-02-14 12:00:00', 'date_end': '2019-02-14 12:10:00'},
#      {'date_start': '2019-02-15 12:00:00', 'date_end': '2019-02-15 12:10:00'},
#      {'date_start': '2019-02-16 12:00:00', 'date_end': '2019-02-16 12:10:00'},
#      {'date_start': '2019-02-17 12:00:00', 'date_end': '2019-02-17 12:10:00'},
#      {'date_start': '2019-02-18 12:00:00', 'date_end': '2019-02-18 12:10:00'},
#      {'date_start': '2019-02-19 12:00:00', 'date_end': '2019-02-19 12:10:00'},
#      {'date_start': '2019-02-20 12:00:00', 'date_end': '2019-02-20 12:10:00'},
#      {'date_start': '2019-02-21 12:00:00', 'date_end': '2019-02-21 12:10:00'},
#      {'date_start': '2019-02-22 12:00:00', 'date_end': '2019-02-22 12:10:00'},
#      {'date_start': '2019-02-23 12:00:00', 'date_end': '2019-02-23 12:10:00'},
#      {'date_start': '2019-02-24 12:00:00', 'date_end': '2019-02-24 12:10:00'},
#      {'date_start': '2019-02-25 12:00:00', 'date_end': '2019-02-25 12:10:00'},
#      {'date_start': '2019-02-26 12:00:00', 'date_end': '2019-02-26 12:10:00'},
#      {'date_start': '2019-02-27 12:00:00', 'date_end': '2019-02-27 12:10:00'},
#      {'date_start': '2019-02-28 12:00:00', 'date_end': '2019-02-28 12:10:00'},
#      {'date_start': '2019-03-01 12:00:00', 'date_end': '2019-03-01 12:10:00'},
#      {'date_start': '2019-03-02 12:00:00', 'date_end': '2019-03-02 12:10:00'},
#      {'date_start': '2019-03-03 12:00:00', 'date_end': '2019-03-03 12:10:00'},
#      {'date_start': '2019-03-04 12:00:00', 'date_end': '2019-03-04 12:10:00'},
#      {'date_start': '2019-03-05 12:00:00', 'date_end': '2019-03-05 12:10:00'},
#      {'date_start': '2019-03-06 12:00:00', 'date_end': '2019-03-06 12:10:00'},
#      {'date_start': '2019-03-07 12:00:00', 'date_end': '2019-03-07 12:10:00'},
#      {'date_start': '2019-03-08 12:00:00', 'date_end': '2019-03-08 12:10:00'},
#      {'date_start': '2019-03-09 12:00:00', 'date_end': '2019-03-09 12:10:00'},
#      {'date_start': '2019-03-10 12:00:00', 'date_end': '2019-03-10 12:10:00'},
#      {'date_start': '2019-03-11 12:00:00', 'date_end': '2019-03-11 12:10:00'},
#      {'date_start': '2019-03-12 12:00:00', 'date_end': '2019-03-12 12:10:00'},
#      {'date_start': '2019-03-13 12:00:00', 'date_end': '2019-03-13 12:10:00'},
#      {'date_start': '2019-03-14 12:00:00', 'date_end': '2019-03-14 12:10:00'},
#      {'date_start': '2019-03-15 12:00:00', 'date_end': '2019-03-15 12:10:00'},
#      {'date_start': '2019-03-16 12:00:00', 'date_end': '2019-03-16 12:10:00'},
#      {'date_start': '2019-03-17 12:00:00', 'date_end': '2019-03-17 12:10:00'},
#      {'date_start': '2019-03-18 12:00:00', 'date_end': '2019-03-18 12:10:00'},
#      {'date_start': '2019-03-19 12:00:00', 'date_end': '2019-03-19 12:10:00'},
#      {'date_start': '2019-03-20 12:00:00', 'date_end': '2019-03-20 12:10:00'},
#      {'date_start': '2019-03-21 12:00:00', 'date_end': '2019-03-21 12:10:00'},
#      {'date_start': '2019-03-22 12:00:00', 'date_end': '2019-03-22 12:10:00'},
#      {'date_start': '2019-03-23 12:00:00', 'date_end': '2019-03-23 12:10:00'},
#      {'date_start': '2019-03-24 12:00:00', 'date_end': '2019-03-24 12:10:00'},
#      {'date_start': '2019-03-25 12:00:00', 'date_end': '2019-03-25 12:10:00'},
#      {'date_start': '2019-03-26 12:00:00', 'date_end': '2019-03-26 12:10:00'},
#      {'date_start': '2019-03-27 12:00:00', 'date_end': '2019-03-27 12:10:00'},
#      {'date_start': '2019-03-28 12:00:00', 'date_end': '2019-03-28 12:10:00'},
#      {'date_start': '2019-03-29 12:00:00', 'date_end': '2019-03-29 12:10:00'},
#      {'date_start': '2019-03-30 12:00:00', 'date_end': '2019-03-30 12:10:00'},
#      {'date_start': '2019-03-31 12:00:00', 'date_end': '2019-03-31 12:10:00'},
#      {'date_start': '2019-04-01 12:00:00', 'date_end': '2019-04-01 12:10:00'},
#      {'date_start': '2019-04-02 12:00:00', 'date_end': '2019-04-02 12:10:00'},
#      {'date_start': '2019-04-03 12:00:00', 'date_end': '2019-04-03 12:10:00'},
#      {'date_start': '2019-04-04 12:00:00', 'date_end': '2019-04-04 12:10:00'},
#      {'date_start': '2019-04-05 12:00:00', 'date_end': '2019-04-05 12:10:00'},
#      {'date_start': '2019-04-06 12:00:00', 'date_end': '2019-04-06 12:10:00'},
#      {'date_start': '2019-04-07 12:00:00', 'date_end': '2019-04-07 12:10:00'},
#      {'date_start': '2019-04-08 12:00:00', 'date_end': '2019-04-08 12:10:00'},
#      {'date_start': '2019-04-09 12:00:00', 'date_end': '2019-04-09 12:10:00'},
#      {'date_start': '2019-04-10 12:00:00', 'date_end': '2019-04-10 12:10:00'},
#      {'date_start': '2019-04-11 12:00:00', 'date_end': '2019-04-11 12:10:00'},
#      {'date_start': '2019-04-12 12:00:00', 'date_end': '2019-04-12 12:10:00'},
#      {'date_start': '2019-04-13 12:00:00', 'date_end': '2019-04-13 12:10:00'},
#      {'date_start': '2019-04-14 12:00:00', 'date_end': '2019-04-14 12:10:00'},
#      {'date_start': '2019-04-15 12:00:00', 'date_end': '2019-04-15 12:10:00'},
#      {'date_start': '2019-04-16 12:00:00', 'date_end': '2019-04-16 12:10:00'},
#      {'date_start': '2019-04-17 12:00:00', 'date_end': '2019-04-17 12:10:00'},
#      {'date_start': '2019-04-18 12:00:00',
#       'date_end': '2019-04-18 12:10:00'}]}]}}

# %% [markdown]
# Using the term vector API, let's investigate the term vector for the description field of the document above (id _AV19Sgi4jk6MoKTLfifp_). Note in the call to the `termvectors` method, we explicitly request the term statistics `term_statistics=True`.

# %%
# curl -X GET localhost:9200/goma/event/AV19Sgi4jk6MoKTLfifp/_termvectors?term_statistics&fields=description
res = es.termvectors(index='goma', doc_type='event', id='AV19Sgi4jk6MoKTLfifp', 
                     fields=['description'], term_statistics=True)

# We don't really care that much about the additional info, let's get straight to the point.
tv = res['term_vectors']['description']
tv
# Out:
# --------------------------------------------------
# KeyError         Traceback (most recent call last)
# <ipython-input-7-bd0e1327f4f2> in <module>
#       4
#       5 # We don't really care that much about the additional info, let's get straight to the point.
# ----> 6 tv = res['term_vectors']['description']
#       7 tv
#
# KeyError: 'term_vectors'

# %% [markdown]
# That's a big json object, so let's break it down into some digestable tables. Firstly, let's take a look at the field statistics.
#
#  - `doc_count`: document count (how many documents contain this field)
#  - `sum_doc_freq`: sum of document frequencies (the sum of document frequencies for all terms in this field)
#  - `sum_ttf`: sum of total term frequencies (the sum of total term frequencies of each term in this field)

# %%
pd.DataFrame(tv['field_statistics'], index=['count'])
# Out:
# --------------------------------------------------
# NameError        Traceback (most recent call last)
# <ipython-input-8-e4c30b4c451c> in <module>
# ----> 1 pd.DataFrame(tv['field_statistics'], index=['count'])
#
# NameError: name 'tv' is not defined

# %% [markdown]
# More importantly, we can also see the breakdown of the term statistics in the document for each term in the document. These tables omit the `tokens` field, however this is can be used to extract the location of the term in the document.
#
#  - `term_freq`: term frequency in the field
#  - `doc_freq`: document frequency (the number of documents containing the current term)
#  - `ttf`: sum of total term frequencies (the sum of total term frequencies of each term in this field)

# %%
terms = []
for term in tv['terms']:
    term_info = tv['terms'][term].copy()
    del(term_info['tokens'])
    term_info.update({'term': term})
    terms.append(term_info)
df = pd.DataFrame(terms).set_index('term')
df[0:10]
# Out:
#             doc_freq  term_freq  ttf
# term
# 22                 1          1    1
# a                 28          1   37
# aboriginal         2          1    3
# absence            1          1    1
# adornments         1          1    1
# and               23          5   73
# are                3          1    3
# as                 9          1   12
# associated         1          1    1
# banumbirr          1          1    1

# %%
# Sorted by doc_freq
df.sort_values(by='doc_freq', ascending=False)[0:10]
# Out:
#        doc_freq  term_freq  ttf
# term
# a            28          1   37
# the          25          3   85
# of           24          2   54
# and          23          5   73
# for          14          1   14
# to           14          1   24
# from         11          3   20
# as            9          1   12
# with          7          2   12
# works         6          2    8

# %%
# Sorted by term_freq
df.sort_values(by='term_freq', ascending=False)[0:10]
# Out:
#           doc_freq  term_freq  ttf
# term
# and             23          5   73
# the             25          3   85
# from            11          3   20
# works            6          2    8
# of              24          2   54
# cultures         1          2    2
# with             7          2   12
# lucent           1          1    1
# majesty          1          1    1
# metre            1          1    1

# %%
# Sorted by ttf
df.sort_values(by='ttf', ascending=False)[0:10]
# Out:
#        doc_freq  term_freq  ttf
# term
# the          25          3   85
# and          23          5   73
# of           24          2   54
# a            28          1   37
# to           14          1   24
# from         11          3   20
# for          14          1   14
# with          7          2   12
# as            9          1   12
# works         6          2    8

# %% [markdown]
# #### Exercise 1
#
# Repeat the expoloration of the term vector for a document using the ClueWeb12 sample index you have built in previous activities.
#
# #### Exercise 2 -- advanced
#
# Using the Clueweb12 sample index, identify two documents that contain a query term of your choice (suggestion: after having chosen a term, query the index to retrieve the top 2 documents that satisfy the query). Then, compute the [cosine similarity](https://en.wikipedia.org/wiki/Cosine_similarity) between the two term vectors.
